# %% [markdown]
# # EDA on iris dataset

# %% [markdown]
# ### Life cycle of Machine learning Project

# %% [markdown]
# 1.Understanding the Problem Statement
# 2.Data Collection
# 3.Exploratory data analysis
# 4.Data Cleaning
# 5.Data Pre-Processing
# 6.Model Training
# 7.Choose best model

# %% [markdown]
# ## 1.Problem Statement:

# %% [markdown]
# We have to apply explotary data analysis on this dataset to find out which attribute is useful to classify the diffences in flower

# %% [markdown]
# ## 2.Data Collection:

# %% [markdown]
# Dataset link: https://github.com/dharavathramdas101/EDA

# %% [markdown]
# ## 2.1 Iris Flower Dataset Description

# %% [markdown]
# 1. A simple dataset to learn the basics
# 2. iris dataet was introduced by ronaod fisher, a british biologist in 1936. 3. the dataset has 150 observations, around 50 for each species of Iris - setosa, virginica and versicolor.
# 4. ther are 4 features measured on each sample - length and the width of sepal and petal, in centimeters.
# 5. fisher built a linear discriminant model to distinguish the species using 4 features

# %% [markdown]
# Attributes :-
#     1. Sepal length in cm
#     2. Sepal width in cm
#     3. Petal length in cm
#     4. Petal width in cm
#     5. class: -- Iris Setosa -- Iris Versicolour -- Iris Virginica
# NOTE - Class contains 3 different types of flowers

# %%
from IPython.display import Image
Image(filename=r"C:\Users\DHARAVATH RAMDAS\OneDrive\Pictures\iris1.png")

# %% [markdown]
# ## 2.2 importing Data and Required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## 2.3 Load the dataset

# %%
df = pd.read_csv(r"C:\Users\DHARAVATH RAMDAS\Downloads\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
Image(filename=r"C:\Users\DHARAVATH RAMDAS\OneDrive\Pictures\iris2.png")

# %% [markdown]
# Observation:
# 1. see the data columns and the flower how we are caluculated the sepal length, sepal width, petal length, petal width
# 2. we have to drop the id  because it is not that much use

# %%
df.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# ### we have to drop the id  because it is not that much use

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df.head(4)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa

# %% [markdown]
# ### Use the function shape to find the dimentions of the dataframe.

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# Observation:
#     dataset have 150 rows and 5 columns

# %% [markdown]
# ### check columns information

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### Type of columns

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# ### Check the data balanced or imbalanced

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# Observation:
#     see it is balanced dataset

# %% [markdown]
# ## Dataset Description

# %%
### Describe function is used to see the statistics of the dataset such as mean, median, standard deviation

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### transpose the describe

# %%
df.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# ### Describing the setosa class

# %%
iris_setosa = df.loc[df['Species']=="Iris-setosa"]
iris_setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %% [markdown]
# ### Describing the iris versicolot

# %%
iris_versicolor = df.loc[df['Species']=="Iris-versicolor"]
iris_versicolor.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      50.000000     50.000000      50.000000     50.000000
# mean        5.936000      2.770000       4.260000      1.326000
# std         0.516171      0.313798       0.469911      0.197753
# min         4.900000      2.000000       3.000000      1.000000
# 25%         5.600000      2.525000       4.000000      1.200000
# 50%         5.900000      2.800000       4.350000      1.300000
# 75%         6.300000      3.000000       4.600000      1.500000
# max         7.000000      3.400000       5.100000      1.800000

# %% [markdown]
# ### Describing the iris virginica

# %%
iris_virginica = df.loc[df['Species']=="Iris-virginica"]
iris_virginica.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         6.58800      2.974000       5.552000       2.02600
# std          0.63588      0.322497       0.551895       0.27465
# min          4.90000      2.200000       4.500000       1.40000
# 25%          6.22500      2.800000       5.100000       1.80000
# 50%          6.50000      3.000000       5.550000       2.00000
# 75%          6.90000      3.175000       5.875000       2.30000
# max          7.90000      3.800000       6.900000       2.50000

# %% [markdown]
# ### we need to verify the features are of which datatypes. we use info() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Observation:
#     1.total index are 150 from 0 to 149
#     2.total 5 columns
#     3.total 4 columns are folat64 data type
#     4.and 1 column are object
#     5. memory usage is 6.0kb

# %% [markdown]
# ### Check the null values

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Observation:
#     see we dont have any null values in dataset

# %% [markdown]
# ### we are seperating the numerical and categorical

# %%
#check the datatype of column

df['Species'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Categorical Feature

# %%
cat_col=[fea for fea in df.columns if df[fea].dtype == 'O']
df[cat_col].head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# ## Numerical Features

# %%
num_col=[fea for fea in df.columns if df[fea].dtype != 'O']

# %%
df[num_col].head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %% [markdown]
# observation: we have the 14 num columns

# %% [markdown]
# # 3. Exploring data

# %% [markdown]
# ## 3.1 Univariate Analysis

# %% [markdown]
# The term univariate analysis refers to the analysis of one variable

# %% [markdown]
# ## Numerical Features

# %% [markdown]
# ### 1-D Scatter plot

# %% [markdown]
# This plots different observations/values of the same variable corresponding to the index/observation number

# %% [markdown]
# ### scatter plot on sepallenght

# %%
plt.scatter(df.index,df['SepalLengthCm'])

# %% [markdown]
# Observation:
#     see the sepal lenght is how it is spread

# %% [markdown]
# ### scatter plot on sepalwidth

# %%
plt.scatter(df.index,df['SepalWidthCm'])

# %% [markdown]
# ### scatter plot on petallength

# %%
plt.scatter(df.index,df['PetalLengthCm'])

# %% [markdown]
# ### scatter plot on petalwidth

# %%
plt.scatter(df.index,df['PetalWidthCm'])

# %% [markdown]
# ## 3.2 Histograms

# %% [markdown]
# A histogram groups values into ranges (or bins), and the height of a bar shows how many values fall in that range.

# %%
plt.figure(figsize=(12,8))
plt.title("hi")
for i in range(0,len(num_col)):
    plt.subplot(2,2,i+1)
    sns.histplot(x=num_col[i],data=df)
    plt.xlabel(num_col[i])

# %% [markdown]
# ## 3.3 Histogram plot with KDE

# %% [markdown]
# We can display a histogram with a KDE curve as below

# %%
plt.figure(figsize=(12,9))
plt.title("hi")
for i in range(0,len(num_col)):
    plt.subplot(2,2,i+1)
    sns.histplot(x=num_col[i],data=df,kde=True)
    plt.xlabel(num_col[i])

# %% [markdown]
# ## 3.4 KDE plot

# %% [markdown]
# kde plot shows the how much data is spreaded

# %% [markdown]
# ### kde plot on sepallenght

# %%
sns.kdeplot(x='SepalLengthCm',data=df,hue='Species')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %% [markdown]
# ### kde plot Sepallenght

# %%
sns.kdeplot(x='SepalWidthCm',data=df,hue='Species')
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %% [markdown]
# ### kde plot on petallength

# %%
sns.kdeplot(x='PetalLengthCm',data=df,hue='Species')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %% [markdown]
# ### kde plot on petalwidth

# %%
sns.kdeplot(x='PetalWidthCm',data=df,hue='Species')
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# ## 3.5 Box plots:

# %% [markdown]
# A boxplot shows the distribution, center and skewness of a numeric feature. It divides the data into sections that contain 25% of the data approximately.
#
# Outliers, if present, appear as dots on either end. The whiskers that extend from the box represent the minimum and maximum values. The box depicts the Interquartile range and holds 50% of the data.

# %%
plt.figure(figsize=(12,8))
plt.title("hi")
for i in range(0,len(num_col)):
    plt.subplot(2,2,i+1)
    sns.boxplot(x=df[num_col[i]])
    plt.xlabel(num_col[i])

# %% [markdown]
# Observation:
#     see the sepalwidth conatins the some of outlaier and other dont have the out outlaiers

# %% [markdown]
# ## 3.6 Visualizing Categorical Variables

# %% [markdown]
# ### Plot for species

# %%
plt.plot(df["Species"])
plt.xlabel("no of data points")
plt.show()

# %% [markdown]
# observation:
#     see the plot it contains 50 iris-setosa, 50 iris-versicolor and 50 iris-virginica

# %% [markdown]
# ### hist plot

# %%
plt.hist(df['Species'],color="green")
plt.show()

# %% [markdown]
# observation:
#     see total 150 in that 50 iris-setosa, 50 iris-versicolor and 50 iris-virginica

# %% [markdown]
# ## 4. Bivariate Analysis

# %% [markdown]
# ### 4.1 2-D Scatter Plot

# %% [markdown]
# ### scatter plot on sepallenght and sepalwidth with out hue

# %%
sns.scatterplot(data=df,x="SepalLengthCm",y="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ### Scatter on sepallenght and sepalwidth plot with hue

# %%
sns.scatterplot(data=df,x="SepalLengthCm",y="SepalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# Observation:
#     using sepal lenght and sepal width, we can seperate setosa flower from others

# %% [markdown]
# ### Scatter plot on petallenght and petalwidth

# %%
sns.scatterplot(data=df,x="PetalLengthCm",y="PetalWidthCm")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# ### Scattet plot on petallength and petalwidth with hue

# %%
sns.scatterplot(data=df,x="PetalLengthCm",y="PetalWidthCm",hue="Species")
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# observation:
#     we can seperate the setosa and also versicolor

# %% [markdown]
# # 5. Correlation

# %% [markdown]
# 1.Now we will do some plotting/visualizing our data to understand the relation ship between the numerical features.
# 2.I have used seaborn library for plotting, we can also use python matplotlib library to visualize the data.
# 3.There are different types of plots like bar plot, box plot, scatter plot etc.
# 4.Scatter plot is very useful when we are analyzing the relation ship between 2 features on x and y axis.
# 5.In seaborn library we have pairplot function which is very useful to scatter plot all the features at once instead of plotting them individually.

# %% [markdown]
# ## 5.1 Pairplot:

# %%
sns.set_style("whitegrid")
sns.pairplot(df,hue="Species",size=3)
plt.show()
# Out:
# C:\Users\DHARAVATH RAMDAS\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Observations:
#  1. petal_length and petal_width are the most useful features to identify various flower types.
#  2. While Setosa can be easily identified (linearly seperable), Virginica and Versicolor have some overlap (almost linearly           seperable).
#  3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# ## 5.2 Heatmap:

# %% [markdown]
# we will see how these features are correlated to each other using heatmap in seaborn library

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# observation:
#     1.petallenght and petalwidth has the high correlation
#     2.less correlation is sepallenght and sepal width

# %% [markdown]
# ## 6.Histogram, PDF and CDF

# %% [markdown]
# histogram shows the how much it is spreaded

# %% [markdown]
# ### distribution plot on sepallenght

# %%
d=sns.FacetGrid(data=df,hue="Species",size=6)
d.map(sns.distplot,"SepalLengthCm")
d.add_legend()

# %% [markdown]
# ### dist plot on sepal width

# %%
e=sns.FacetGrid(data=df,hue="Species",size=6)
e.map(sns.distplot,"SepalWidthCm")
e.add_legend()

# %% [markdown]
# ## dist plot on petal lenght

# %%
f=sns.FacetGrid(data=df,hue="Species",size=6)
f.map(sns.distplot,"PetalLengthCm")
f.add_legend()

# %% [markdown]
# ## distplot on petal width

# %%
g=sns.FacetGrid(data=df,hue="Species",size=6)
g.map(sns.distplot,"PetalWidthCm")
g.add_legend()

# %% [markdown]
# ## 7.Plot CDF

# %% [markdown]
# ### Plot CDF for petal length

# %%
# Cumulative distribution function(cdf)

# %%
counts,bin_edges=np.histogram(iris_setosa["PetalLengthCm"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# compute cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %% [markdown]
# Observation:
#     1. orange line is cdf
#     2. blue line is pdf

# %% [markdown]
# ### plot cdf on petal lenght

# %%
counts,bin_edges=np.histogram(iris_setosa["PetalWidthCm"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# compute cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.12 0.   0.56 0.14 0.   0.   0.14 0.   0.02 0.02]
# [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6 ]

# %% [markdown]
# ### plot cdf on sepal lenght

# %%
counts,bin_edges=np.histogram(iris_setosa["SepalLengthCm"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# compute cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.08 0.02 0.12 0.1  0.24 0.16 0.08 0.1  0.04 0.06]
# [4.3  4.45 4.6  4.75 4.9  5.05 5.2  5.35 5.5  5.65 5.8 ]

# %% [markdown]
# ### plot cdf on sepal lenght

# %%
counts,bin_edges=np.histogram(iris_setosa["SepalWidthCm"],bins=10,density=True)
pdf=counts/(sum(counts))
print(pdf)
print(bin_edges)

# compute cdf
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.show()
# Out:
# [0.02 0.   0.02 0.22 0.14 0.3  0.1  0.12 0.04 0.04]
# [2.3  2.51 2.72 2.93 3.14 3.35 3.56 3.77 3.98 4.19 4.4 ]

# %% [markdown]
# ## 8.Mean, Variance and Standard Deviation

# %%
print('Means:')
print(np.mean(iris_setosa["PetalLengthCm"]))
print(np.mean(iris_versicolor["PetalLengthCm"]))
print(np.mean(iris_virginica["PetalLengthCm"]))

print('\nstandard deviation:')
print(np.std(iris_setosa["PetalLengthCm"]))
print(np.std(iris_versicolor["PetalLengthCm"]))
print(np.std(iris_virginica["PetalLengthCm"]))
# Out:
# Means:
# 1.464
# 4.26
# 5.552
#
# standard deviation:
# 0.17176728442867115
# 0.4651881339845204
# 0.5463478745268441

# %% [markdown]
# Obsevations:
#  MEAN:
#  51st flower length is added to our data and it is wrong i.e huge value is inserted in our case its 50, but actual length        will be 1-2 so the mean is changed drastically, so following only mean is not feasible, similarly std also

# %% [markdown]
# ## Median, Percentile, Quantile, IQR, MAD

# %%
print("\nMedians:")
print(np.median(iris_setosa["PetalLengthCm"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["PetalLengthCm"],50)));
print(np.median(iris_virginica["PetalLengthCm"]))
print(np.median(iris_versicolor["PetalLengthCm"]))


print("\nQuantiles:")
print(np.percentile(iris_setosa["PetalLengthCm"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["PetalLengthCm"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["PetalLengthCm"], np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(iris_setosa["PetalLengthCm"],90))
print(np.percentile(iris_virginica["PetalLengthCm"],90))
print(np.percentile(iris_versicolor["PetalLengthCm"], 90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["PetalLengthCm"]))
print(robust.mad(iris_virginica["PetalLengthCm"]))
print(robust.mad(iris_versicolor["PetalLengthCm"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# 90th Percentiles:
# 1.7
# 6.31
# 4.8
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# Observations:
#  MEDIAN:
#  Even after Adding Outlier the result is almost same.because if there are more than 50% of outliers then result will be          useless.So its better than mean and std.

# %% [markdown]
# ## 9.Box plot and Whiskers

# %%
#Box-plot with whiskers: another method of visualizing the  1-D scatter plot more intuitivey.


#NOTE: IN the plot below, a technique call inter-quartile range is used in plotting the whiskers. 
#Whiskers in the plot below do not correposnd to the min and max values.

#Box-plot can be visualized as a PDF on the side-ways.

sns.boxplot(x='Species',y='PetalLengthCm', data=df)
plt.show()

# %% [markdown]
# ### boxplot on species and petalwidth

# %%
sns.boxplot(x='Species',y='PetalWidthCm', data=df)
plt.show()

# %% [markdown]
# ### boxplot on species and sepallenght

# %%
sns.boxplot(x='Species',y='SepalLengthCm', data=df)
plt.show()

# %% [markdown]
# ### boxplot on species and sepalwidth

# %%
sns.boxplot(x='Species',y='SepalWidthCm', data=df)
plt.show()

# %% [markdown]
# ## 10.Violin plots

# %% [markdown]
# ### violin plot on species and petallenght

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them

# Denser regions of the data are fatter, and sparser ones thinner in a violin plot

sns.violinplot(x="Species", y="PetalLengthCm", data=df, size=8)
plt.show()

# %% [markdown]
# ### violin plot on species and petalwidth

# %%
sns.violinplot(x="Species", y="PetalWidthCm", data=df, size=8)
plt.show()

# %% [markdown]
# ### violin plot on species and sepallenght

# %%
sns.violinplot(x="Species", y="SepalLengthCm", data=df, size=8)
plt.show()

# %% [markdown]
# ### violin plot on species and sepalwidth

# %%
sns.violinplot(x="Species", y="SepalWidthCm", data=df, size=8)
plt.show()

# %% [markdown]
# ## 11.Multivariate probability density and contour plot

# %%
sns.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=iris_setosa, kind="kde")
plt.show()

# %% [markdown]
# Observations:
#  In this 2d plot Dark layer indicates more points and light layers or hills is called less points.
#  These light to dark lines is called contours. This graph is called Contours probability density plot.

# %%
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_setosa, kind="kde")
plt.show()

# %% [markdown]
# Observations:
#  In this 2d plot Dark layer indicates more points and light layers or hills is called less points.
#  These light to dark lines is called contours. This graph is called Contours probability density plot

# %% [markdown]
# # Logistic regression implementation on iris

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import  accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# %%
df.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# ## Independent and Dependent feature seperation

# %% [markdown]
# ### independent feature

# %%
X = df.drop('Species',axis=1)

# %% [markdown]
# ### Dependent feature

# %%
y = df['Species']

# %%
### Checking

# %%
X.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2

# %%
y.head(3)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# ## Spliting the data into train and test split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state= 355)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (112, 4) (112,)

# %%
print(X_test.shape,y_test.shape)
# Out:
# (38, 4) (38,)

# %% [markdown]
# ## Standardizing or Feature scalling dataset

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
# Apply data

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.20391445, -0.73732267,  0.77791956,  0.54928847],
#        [-1.75017481,  0.42577788, -1.43224442, -1.35620782],
#        [ 0.57030618,  0.65839799,  1.30137944,  1.77425037],
#        [-1.87230539, -0.03946234, -1.54856884, -1.49231469],
#        [ 0.81456734, -0.03946234,  0.83608177,  1.09371598],
#        [-1.01739134,  1.12363821, -1.25775779, -0.81178031],
#        [ 0.69243676,  0.19315777,  1.01056839,  0.82150223],
#        [ 0.32604503, -0.03946234,  0.48710851,  0.27707471],
#        [-1.26165249, -0.03946234, -1.37408221, -1.49231469],
#        [ 1.18095908, -0.50470256,  0.60343293,  0.27707471],
#        [-0.16247729, -0.50470256,  0.19629746,  0.14096784],
#        [ 0.08178387, -0.03946234,  0.77791956,  0.82150223],
#        [-1.13952192,  0.19315777, -1.31592   , -1.49231469],
#        [-1.50591365,  0.42577788, -1.37408221, -1.35620782],
#        [ 1.54735081, -0.03946234,  1.24321723,  1.22982286],
#        [-0.52886902, -0.03946234,  0.4289463 ,  0.41318159],
#        [-0.40673844, -1.20256289,  0.13813525,  0.14096784],
#        [-1.75017481, -0.27208245, -1.37408221, -1.35620782],
#        [ 0.32604503, -0.03946234,  0.66159514,  0.82150223],
#        [-1.13952192, -1.435183  , -0.26900022, -0.2673528 ],
#        [-0.40673844, -1.66780311,  0.13813525,  0.14096784],
#        [ 0.44817561,  0.8910181 ,  0.95240618,  1.50203661],
#        [-0.40673844, -1.435183  , -0.03635138, -0.2673528 ],
#        [ 0.57030618, -1.20256289,  0.66159514,  0.41318159],
#        [-0.89526076,  1.82149853, -1.08327116, -1.08399406],
#        [-0.89526076,  1.58887843, -1.31592   , -1.08399406],
#        [-1.01739134, -2.36566343, -0.1526758 , -0.2673528 ],
#        [ 1.0588285 ,  0.65839799,  1.12689281,  1.22982286],
#        [ 0.20391445, -1.90042321,  0.13813525, -0.2673528 ],
#        [ 0.57030618, -1.66780311,  0.37078409,  0.14096784],
#        [-0.16247729, -0.96994278, -0.1526758 , -0.2673528 ],
#        [-0.52886902,  2.05411864, -1.43224442, -1.08399406],
#        [-1.13952192,  0.19315777, -1.31592   , -1.49231469],
#        [-1.26165249,  0.8910181 , -1.25775779, -1.35620782],
#        [ 0.81456734, -0.50470256,  0.48710851,  0.41318159],
#        [-1.50591365,  0.8910181 , -1.37408221, -1.22010094],
#        [ 0.44817561, -0.27208245,  0.31262188,  0.14096784],
#        [ 0.93669792, -0.03946234,  0.37078409,  0.27707471],
#        [ 1.79161197, -0.27208245,  1.47586607,  0.82150223],
#        [-1.01739134, -0.03946234, -1.25775779, -1.35620782],
#        [-0.28460787, -1.20256289,  0.07997304, -0.13124592],
#        [-1.26165249,  0.8910181 , -1.08327116, -1.35620782],
#        [ 2.28013428, -0.50470256,  1.70851491,  1.09371598],
#        [-1.01739134,  0.65839799, -1.37408221, -1.35620782],
#        [-0.89526076,  1.12363821, -1.37408221, -1.35620782],
#        [-0.16247729, -0.27208245,  0.25445967,  0.14096784],
#        [-0.40673844,  1.12363821, -1.43224442, -1.35620782],
#        [-0.52886902,  2.05411864, -1.19959558, -1.08399406],
#        [-0.28460787, -0.27208245, -0.09451359,  0.14096784],
#        [ 0.69243676, -0.27208245,  0.31262188,  0.14096784],
#        [ 1.42522023,  0.42577788,  0.54527072,  0.27707471],
#        [-0.89526076,  0.8910181 , -1.31592   , -1.35620782],
#        [ 1.30308965,  0.19315777,  0.66159514,  0.41318159],
#        [-1.62804423, -1.66780311, -1.43224442, -1.22010094],
#        [ 0.57030618, -1.20256289,  0.71975735,  0.9576091 ],
#        [ 0.57030618, -0.27208245,  1.0687306 ,  0.82150223],
#        [-0.28460787, -0.73732267,  0.25445967,  0.14096784],
#        [-0.6509996 ,  1.58887843, -1.31592   , -1.35620782],
#        [ 0.20391445,  0.8910181 ,  0.4289463 ,  0.54928847],
#        [ 0.57030618,  0.65839799,  0.54527072,  0.54928847],
#        [ 1.18095908, -0.03946234,  1.01056839,  1.22982286],
#        [-0.77313018, -0.73732267,  0.07997304,  0.27707471],
#        [-0.52886902,  1.58887843, -1.31592   , -1.35620782],
#        [-1.01739134,  0.8910181 , -1.25775779, -1.08399406],
#        [ 1.30308965,  0.19315777,  0.77791956,  1.50203661],
#        [ 0.08178387,  0.42577788,  0.60343293,  0.82150223],
#        [ 0.20391445, -0.03946234,  0.60343293,  0.82150223],
#        [ 0.57030618, -0.73732267,  0.66159514,  0.82150223],
#        [ 0.20391445, -1.90042321,  0.71975735,  0.41318159],
#        [-1.01739134, -1.66780311, -0.26900022, -0.2673528 ],
#        [ 0.69243676, -0.73732267,  0.89424398,  0.9576091 ],
#        [-1.01739134,  0.8910181 , -1.31592   , -1.35620782],
#        [ 1.0588285 ,  0.19315777,  0.54527072,  0.41318159],
#        [ 0.81456734, -0.03946234,  1.18505502,  1.36592974],
#        [-0.28460787, -0.50470256,  0.66159514,  1.09371598],
#        [-1.50591365,  0.19315777, -1.31592   , -1.35620782],
#        [-1.01739134,  1.35625832, -1.37408221, -1.35620782],
#        [ 0.69243676, -0.50470256,  1.0687306 ,  1.36592974],
#        [ 2.28013428, -0.03946234,  1.35954165,  1.50203661],
#        [-0.28460787, -0.03946234,  0.19629746,  0.14096784],
#        [ 1.66948139, -0.03946234,  1.18505502,  0.54928847],
#        [-0.04034671,  2.28673875, -1.49040663, -1.35620782],
#        [ 0.08178387, -0.03946234,  0.25445967,  0.41318159],
#        [-0.89526076, -1.20256289, -0.44348685, -0.13124592],
#        [-0.16247729, -1.20256289,  0.71975735,  1.09371598],
#        [-0.89526076,  1.82149853, -1.31592   , -1.22010094],
#        [ 0.44817561, -0.50470256,  0.60343293,  0.82150223],
#        [-0.16247729,  1.82149853, -1.19959558, -1.22010094],
#        [ 0.57030618, -0.50470256,  0.77791956,  0.41318159],
#        [ 1.30308965,  0.42577788,  1.12689281,  1.50203661],
#        [-0.16247729,  3.21721919, -1.31592   , -1.08399406],
#        [-0.04034671, -0.73732267,  0.77791956,  0.9576091 ],
#        [-0.52886902,  0.8910181 , -1.19959558, -1.35620782],
#        [ 1.66948139,  1.35625832,  1.35954165,  1.77425037],
#        [ 2.28013428, -0.96994278,  1.82483933,  1.50203661],
#        [ 2.1580037 , -0.03946234,  1.6503527 ,  1.22982286],
#        [ 1.0588285 , -1.20256289,  1.18505502,  0.82150223],
#        [ 1.18095908,  0.42577788,  1.24321723,  1.50203661],
#        [-0.04034671, -0.73732267,  0.07997304,  0.00486096],
#        [-1.13952192, -1.20256289,  0.4289463 ,  0.68539535],
#        [-0.40673844, -1.435183  ,  0.02181083, -0.13124592],
#        [ 0.32604503, -0.50470256,  0.54527072,  0.00486096],
#        [ 1.0588285 , -0.03946234,  0.71975735,  0.68539535],
#        [-1.26165249, -0.03946234, -1.37408221, -1.22010094],
#        [-1.38378307,  0.42577788, -1.25775779, -1.35620782],
#        [-0.52886902,  0.8910181 , -1.31592   , -1.08399406],
#        [-0.16247729, -0.03946234,  0.25445967,  0.00486096],
#        [ 1.0588285 , -0.03946234,  0.83608177,  1.50203661],
#        [ 0.69243676,  0.42577788,  0.4289463 ,  0.41318159],
#        [-1.01739134,  0.42577788, -1.49040663, -1.35620782],
#        [-0.40673844, -0.96994278,  0.37078409,  0.00486096],
#        [ 1.91374255, -0.50470256,  1.35954165,  0.9576091 ]])

# %%
X_test
# Out:
# array([[ 1.30308965,  0.19315777,  0.95240618,  1.22982286],
#        [ 0.93669792, -0.27208245,  0.48710851,  0.14096784],
#        [-0.16247729, -0.50470256,  0.4289463 ,  0.14096784],
#        [ 0.32604503, -0.50470256,  0.13813525,  0.14096784],
#        [ 0.20391445, -0.27208245,  0.4289463 ,  0.41318159],
#        [ 1.66948139,  0.42577788,  1.30137944,  0.82150223],
#        [-0.28460787, -0.03946234,  0.4289463 ,  0.41318159],
#        [ 0.57030618,  0.8910181 ,  1.0687306 ,  1.63814349],
#        [ 0.69243676, -0.50470256,  1.0687306 ,  1.22982286],
#        [ 0.69243676,  0.42577788,  0.89424398,  1.50203661],
#        [ 0.32604503, -0.27208245,  0.54527072,  0.27707471],
#        [ 0.32604503, -0.96994278,  1.0687306 ,  0.27707471],
#        [-0.04034671, -0.50470256,  0.77791956,  1.63814349],
#        [-0.77313018,  2.51935886, -1.31592   , -1.49231469],
#        [-0.89526076,  1.12363821, -1.37408221, -1.22010094],
#        [-1.13952192,  0.19315777, -1.31592   , -1.49231469],
#        [-1.50591365,  1.35625832, -1.60673104, -1.35620782],
#        [-1.38378307,  0.42577788, -1.43224442, -1.35620782],
#        [-0.04034671, -0.96994278,  0.13813525,  0.00486096],
#        [-0.04034671, -0.73732267,  0.77791956,  0.9576091 ],
#        [-1.75017481, -0.03946234, -1.43224442, -1.35620782],
#        [-0.77313018,  1.12363821, -1.31592   , -1.35620782],
#        [-0.77313018,  0.8910181 , -1.37408221, -1.35620782],
#        [ 0.44817561, -1.90042321,  0.4289463 ,  0.41318159],
#        [-0.89526076,  0.65839799, -1.19959558, -0.94788718],
#        [ 1.0588285 ,  0.19315777,  1.0687306 ,  1.63814349],
#        [ 2.28013428,  1.82149853,  1.70851491,  1.36592974],
#        [ 1.0588285 ,  0.65839799,  1.12689281,  1.77425037],
#        [-1.26165249,  0.19315777, -1.25775779, -1.35620782],
#        [ 1.0588285 ,  0.19315777,  0.37078409,  0.27707471],
#        [-0.40673844,  2.75197897, -1.37408221, -1.35620782],
#        [ 2.52439544,  1.82149853,  1.53402828,  1.09371598],
#        [-1.13952192, -0.03946234, -1.37408221, -1.35620782],
#        [-1.01739134,  1.12363821, -1.43224442, -1.22010094],
#        [ 0.81456734, -0.03946234,  1.01056839,  0.82150223],
#        [-0.04034671, -0.73732267,  0.19629746, -0.2673528 ],
#        [ 0.81456734,  0.42577788,  0.77791956,  1.09371598],
#        [-0.89526076,  1.82149853, -1.25775779, -1.35620782]])

# %% [markdown]
# ## Model Training

# %%
logistic_regre = LogisticRegression()
logistic_regre
# Out:
# LogisticRegression()

# %%
logistic_regre.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Prediction

# %%
logistic_regre_pred = logistic_regre.predict(X_test)
logistic_regre_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa'], dtype=object)

# %% [markdown]
# ## Performance Metrics

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix  

confusion_mat = confusion_matrix(y_test,logistic_regre_pred)
confusion_mat
# Out:
# array([[14,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  0, 14]], dtype=int64)

# %%
truly_positive=confusion_mat[0][0]
falsely_positive=confusion_mat[0][1]
falsely_negative=confusion_mat[1][0]
truly_negative=confusion_mat[1][1]

# %% [markdown]
# ## Accuracy Score

# %%
accuracy= round(accuracy_score(y_test,logistic_regre_pred),4)
accuracy
# Out:
# 1.0

# %%
### manual caluculation for accuracy

accuracy_manual=round(((truly_positive+truly_negative)/(truly_positive+falsely_positive+falsely_negative+truly_negative)),4)
print("Accuracy of our model is {}".format(accuracy_manual))
# Out:
# Accuracy of our model is 1.0

# %% [markdown]
# ### Precision Score

# %%
precision_manual= round(truly_positive/(truly_positive+falsely_positive),4)
print("Precision of our model is : ",precision_manual)
# Out:
# Precision of our model is :  1.0

# %% [markdown]
# ### Recall Score

# %%
recall_manual=round(truly_positive/(truly_positive+falsely_negative),4)
print("Recall of our model is {}".format(recall_manual))
# Out:
# Recall of our model is 1.0

# %% [markdown]
# ### F-1 Score

# %%
f1_score=2*(precision_manual*recall_manual)/(precision_manual+recall_manual)
print("F-1 Score of our model is {} ".format(round(f1_score,4)))
# Out:
# F-1 Score of our model is 1.0

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, logistic_regre_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      1.00      1.00        10
#  Iris-virginica       1.00      1.00      1.00        14
#
#        accuracy                           1.00        38
#       macro avg       1.00      1.00      1.00        38
#    weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# follow me on :-
#     Linkedin link: https://www.linkedin.com/in/dharavath-ramdas-a283aa213/
#     GitHub link: https://github.com/dharavathramdas101
